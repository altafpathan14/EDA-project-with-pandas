# %%
import pandas as pd
import numpy as np
pd.set_option("Display.Max_columns",None)

# %%
df=pd.read_csv("C:\\salaries.csv")
print(df)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
print("------------------columns of employee data-------------")
df.columns
# Out:
# ------------------columns of employee data-------------
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
#1.  Display Top 10 Rows of The Dataset
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
#2. Check Last 10 Rows of The Dataset
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle  BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant      0.0
# 148645  148646  Carolyn A Wilson     Human Services Technician      0.0
# 148646  148647      Not provided                  Not provided      NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                     Custodian      0.0
# 148649  148650     Roy I Tillery                     Custodian      0.0
# 148650  148651      Not provided                  Not provided      NaN
# 148651  148652      Not provided                  Not provided      NaN
# 148652  148653      Not provided                  Not provided      NaN
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148644          0.0      0.00       0.0      0.00              0.00  2014
# ...

# %%
#3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
print(df.shape)
print("Rows of dataset=",df.shape[0])
print("columns=",df.shape[1])
# Out:
# (148654, 13)
# Rows of dataset= 148654
# columns= 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
#5. Check Null Values In The Dataset
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
#6. Drop ID, Notes, Agency, and Status Columns
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.drop(columns=['Id','Notes','Agency','Status'])
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
#7. Get Overall Statistics About The Dataframe
df.describe(include="all")
# Out:
#                    Id EmployeeName          JobTitle        BasePay  \
# count   148654.000000       148654            148654  148045.000000
# unique            NaN       110811              2159            NaN
# top               NaN    Kevin Lee  Transit Operator            NaN
# freq              NaN           13              7036            NaN
# mean     74327.500000          NaN               NaN   66325.448840
# std      42912.857795          NaN               NaN   42764.635495
# min          1.000000          NaN               NaN    -166.010000
# 25%      37164.250000          NaN               NaN   33588.200000
# 50%      74327.500000          NaN               NaN   65007.450000
# 75%     111490.750000          NaN               NaN   94691.050000
# max     148654.000000          NaN               NaN  319275.010000
#
#           OvertimePay       OtherPay       Benefits       TotalPay  \
# count   148650.000000  148650.000000  112491.000000  148654.000000
# ...

# %%
#8. Find Occurrence of The Top 5 Employee Names
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df["EmployeeName"].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %%
#9. Find The Number of Unique Job Titles
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %%
#10.Total Number of Job Titles Contain Captain
df[df['JobTitle'].str.contains("CAPTAINS",case=False)].count()# no one belongs to captain
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Notes               0
# Agency              0
# Status              0
# dtype: int64

# %%
#11. Display All the Employee Names From Fire Department
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df[df['JobTitle'].str.contains("Fire",case=False)]["EmployeeName"]
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %%
#12. Find Minimum, Maximum, and Average BasePay
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['BasePay'].dtype
# Out:
# dtype('float64')

# %%
print("maximum basapay=",df['BasePay'].max())
# Out:
# maximum basapay= 319275.01

# %%
print("minimum basepay=",df['BasePay'].min())
# Out:
# minimum basepay= -166.01

# %%
print("average baspay=",df['BasePay'].mean())
# Out:
# average baspay= 66325.4488404877

# %%
#13. Replace 'Not Provided' in EmployeeName' Column to NaN 
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['EmployeeName']=df['EmployeeName'].replace(to_replace=np.nan,value="Not Provided")#df['emp name']=df["emp name"].replace('Not Provided',np.NaN)

# %%
print(df['EmployeeName'])
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
#14. Drop The Rows Having 3 Missing Values
indice=df[df.isnull().sum(axis=1)==3].index

# %%
df.drop(indice,axis=0,inplace=True)

# %%
print("Remaining rows=",df.shape[0])
# Out:
# Remaining rows= 111890

# %%
#15. Find Job Title of ALBERT PARDINI
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
indices=df[df['EmployeeName'].str.contains('ALBERT PARDINI',case=False)].index

# %%
df.loc[indices,['JobTitle']]
# Out:
#                               JobTitle
# 2      CAPTAIN III (POLICE DEPARTMENT)
# 36519                        Captain 3

# %%
#16. How Much ALBERT PARDINI Make (Include Benefits)?
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
indices=df[df["EmployeeName"].str.contains("ALBERT PARDINI",case=False)].index

# %%
df.loc[indices,["TotalPayBenefits"]]
# Out:
#        TotalPayBenefits
# 2             335279.91
# 36519         253995.29

# %%
#17.Display Name of The Person Having The Highest BasePay
df=pd.read_csv("C:\\salaries.csv")
print(df)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['BasePay'].dtype
# Out:
# dtype('float64')

# %%
indices=df['BasePay'].sort_values(ascending=False).head(1).index

# %%
df.loc[indices,['EmployeeName']]
# Out:
#          EmployeeName
# 72925  Gregory P Suhr

# %%
#18.Find Average BasePay of All Employee Per Year
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
for i,v in df.groupby("Year"):
    print(i)
# Out:
# 2011
# 2012
# 2013
# 2014

# %%
df.groupby("Year").get_group(2011)['BasePay'].mean()
# Out:
# 63595.95651677314

# %%
df.groupby("Year").get_group(2012)['BasePay'].mean()
# Out:
# 65436.40685742263

# %%
df.groupby("Year").get_group(2013)['BasePay'].mean()
# Out:
# 69630.03021648065

# %%
df.groupby("Year").get_group(2014)['BasePay'].mean()   #OR
# Out:
# 66564.42192449959

# %%
df.groupby("Year")['BasePay'].agg(["mean"])
# Out:
#               mean
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %%
#19. Find Average BasePay of All Employee Per JobTitle 
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.groupby('JobTitle')['BasePay'].agg(["mean"])
# Out:
#                                                         mean
# JobTitle
# ACCOUNT CLERK                                   43300.806506
# ACCOUNTANT                                      46643.172000
# ACCOUNTANT INTERN                               28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000
# ACUPUNCTURIST                                   66374.400000
# ...                                                      ...
# X-RAY LABORATORY AIDE                           47664.773077
# X-Ray Laboratory Aide                           46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910000
# Youth Comm Advisor                              39077.957500
# ZOO CURATOR                                     43148.000000
#
# [2159 rows x 1 columns]

# %%
#20. Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
for i,v in df.groupby("JobTitle"):
    print(i)
# Out:
# ACCOUNT CLERK
# ACCOUNTANT
# ACCOUNTANT INTERN
# ACPO,JuvP, Juv Prob (SFERS)
# ACUPUNCTURIST
# ADMINISTRATIVE ANALYST
# ADMINISTRATIVE ANALYST II
# ADMINISTRATIVE ANALYST III
# ADMINISTRATIVE ENGINEER
# ADMINISTRATIVE SERVICES MANAGER
# ADMINISTRATOR, SFGH MEDICAL CENTER
# AFFIRMATIVE ACTION SPECIALIST
# AGRICULTURAL INSPECTOR
# AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI
# AIRPORT ASSISTANT DEPUTY DIRECTOR, OPERATIONS
# AIRPORT COMMUNICATIONS OPERATOR
# AIRPORT COMMUNICATIONS SUPERVISOR
# AIRPORT ECONOMIC PLANNER
# AIRPORT ELECTRICIAN
# AIRPORT ELECTRICIAN SUPERVISOR
# AIRPORT EMERGENCY PLANNING COORDINATOR
# AIRPORT MECHANICAL MAINTENANCE SUPERVISOR
# AIRPORT NOISE ABATEMENT SPECIALIST
# AIRPORT OPERATIONS SUPERVISOR
# AIRPORT POLICE SERVICES AIDE
# AIRPORT PROPERTY SPECIALIST I
# AIRPORT SAFETY OFFICER
# ANESTHETIST
# ANIMAL CARE ASSISTANT SUPERVISOR
# ANIMAL CARE ATTENDANT
# ANIMAL CARE SUPERVISOR
# ANIMAL CONTROL OFFICER
# ANIMAL HEALTH TECHNICIAN
# ANIMAL KEEPER
# ...

# %%
print("Average BasePay of Employee Having Job Title ACCOUNTANT")
df.groupby("JobTitle").get_group("ACCOUNTANT")["BasePay"].mean()
# Out:
# Average BasePay of Employee Having Job Title ACCOUNTANT
# 46643.172

# %%
#21. Find Top 5 Most Common Jobs
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
print("Find Top 5 Most Common Jobs")                 #df['JobTitle'].value_counts().head()

df.groupby('JobTitle').size().sort_values(ascending=False).head()
# Out:
# Find Top 5 Most Common Jobs
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# dtype: int64
